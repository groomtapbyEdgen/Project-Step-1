# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.1-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.1-cp314-cp314-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.4 MB 516.9 kB/s eta 0:00:24
#    -- ------------------------------------- 0.8/12.4 MB 776.5 kB/s eta 0:00:16
#    -- ------------------------------------- 0.8/12.4 MB 776.5 kB/s eta 0:00:16
#    -- ------------------------------------- 0.8/12.4 MB 776.5 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.3/12.4 MB 780.2 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.3/12.4 MB 780.2 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.3/12.4 MB 780.2 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.3/12.4 MB 780.2 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.8/12.4 MB 706.7 kB/s eta 0:00:16
#    ----- ---------------------------------- 1.8/12.4 MB 706.7 kB/s eta 0:00:16
#    ----- ---------------------------------- 1.8/12.4 MB 706.7 kB/s eta 0:00:16
#    ------ --------------------------------- 2.1/12.4 MB 621.7 kB/s eta 0:00:17
#    ------ --------------------------------- 2.1/12.4 MB 621.7 kB/s eta 0:00:17
#    ------- -------------------------------- 2.4/12.4 MB 640.2 kB/s eta 0:00:16
#    ------- -------------------------------- 2.4/12.4 MB 640.2 kB/s eta 0:00:16
#    ------- -------------------------------- 2.4/12.4 MB 640.2 kB/s eta 0:00:16
#    --------- ------------------------------ 2.9/12.4 MB 657.1 kB/s eta 0:00:15
#    --------- ------------------------------ 2.9/12.4 MB 657.1 kB/s eta 0:00:15
#    ---------- ----------------------------- 3.1/12.4 MB 651.6 kB/s eta 0:00:15
#    ---------- ----------------------------- 3.1/12.4 MB 651.6 kB/s eta 0:00:15
#    ---------- ----------------------------- 3.4/12.4 MB 667.6 kB/s eta 0:00:14
#    ---------- ----------------------------- 3.4/12.4 MB 667.6 kB/s eta 0:00:14
#    ---------- ----------------------------- 3.4/12.4 MB 667.6 kB/s eta 0:00:14
#    ---------- ----------------------------- 3.4/12.4 MB 667.6 kB/s eta 0:00:14
#    ----------- ---------------------------- 3.7/12.4 MB 590.1 kB/s eta 0:00:15
#    ----------- ---------------------------- 3.7/12.4 MB 590.1 kB/s eta 0:00:15
#    ----------- ---------------------------- 3.7/12.4 MB 590.1 kB/s eta 0:00:15
#    ----------- ---------------------------- 3.7/12.4 MB 590.1 kB/s eta 0:00:15
#    ------------ --------------------------- 3.9/12.4 MB 567.2 kB/s eta 0:00:15
#    ------------ --------------------------- 3.9/12.4 MB 567.2 kB/s eta 0:00:15
#    -------------- ------------------------- 4.5/12.4 MB 599.3 kB/s eta 0:00:14
#    -------------- ------------------------- 4.5/12.4 MB 599.3 kB/s eta 0:00:14
#    --------------- ------------------------ 4.7/12.4 MB 607.8 kB/s eta 0:00:13
#    ---------------- ----------------------- 5.0/12.4 MB 617.0 kB/s eta 0:00:13
#    ---------------- ----------------------- 5.0/12.4 MB 617.0 kB/s eta 0:00:13
#    ---------------- ----------------------- 5.2/12.4 MB 625.7 kB/s eta 0:00:12
#    ----------------- ---------------------- 5.5/12.4 MB 630.1 kB/s eta 0:00:12
#    ----------------- ---------------------- 5.5/12.4 MB 630.1 kB/s eta 0:00:12
#    ------------------ --------------------- 5.8/12.4 MB 634.7 kB/s eta 0:00:11
#    ------------------ --------------------- 5.8/12.4 MB 634.7 kB/s eta 0:00:11
#    ------------------- -------------------- 6.0/12.4 MB 637.0 kB/s eta 0:00:11
#    -------------------- ------------------- 6.3/12.4 MB 656.0 kB/s eta 0:00:10
#    --------------------- ------------------ 6.6/12.4 MB 666.5 kB/s eta 0:00:09
#    --------------------- ------------------ 6.6/12.4 MB 666.5 kB/s eta 0:00:09
#    --------------------- ------------------ 6.8/12.4 MB 664.5 kB/s eta 0:00:09
#    ---------------------- ----------------- 7.1/12.4 MB 669.0 kB/s eta 0:00:09
#    ---------------------- ----------------- 7.1/12.4 MB 669.0 kB/s eta 0:00:09
#    ---------------------- ----------------- 7.1/12.4 MB 669.0 kB/s eta 0:00:09
#    ----------------------- ---------------- 7.3/12.4 MB 655.0 kB/s eta 0:00:08
#    ----------------------- ---------------- 7.3/12.4 MB 655.0 kB/s eta 0:00:08
#    ------------------------ --------------- 7.6/12.4 MB 657.1 kB/s eta 0:00:08
#    ------------------------ --------------- 7.6/12.4 MB 657.1 kB/s eta 0:00:08
#    ------------------------- -------------- 7.9/12.4 MB 654.7 kB/s eta 0:00:07
#    -------------------------- ------------- 8.1/12.4 MB 665.6 kB/s eta 0:00:07
#    -------------------------- ------------- 8.4/12.4 MB 672.7 kB/s eta 0:00:07
#    --------------------------- ------------ 8.7/12.4 MB 675.7 kB/s eta 0:00:06
#    ---------------------------- ----------- 8.9/12.4 MB 689.0 kB/s eta 0:00:06
#    ---------------------------- ----------- 8.9/12.4 MB 689.0 kB/s eta 0:00:06
#    ----------------------------- ---------- 9.2/12.4 MB 687.5 kB/s eta 0:00:05
#    ------------------------------ --------- 9.4/12.4 MB 691.2 kB/s eta 0:00:05
#    ------------------------------ --------- 9.4/12.4 MB 691.2 kB/s eta 0:00:05
#    ------------------------------- -------- 9.7/12.4 MB 691.4 kB/s eta 0:00:04
#    ------------------------------- -------- 9.7/12.4 MB 691.4 kB/s eta 0:00:04
#    -------------------------------- ------- 10.0/12.4 MB 688.5 kB/s eta 0:00:04
#    -------------------------------- ------- 10.2/12.4 MB 696.1 kB/s eta 0:00:04
#    -------------------------------- ------- 10.2/12.4 MB 696.1 kB/s eta 0:00:04
#    --------------------------------- ------ 10.5/12.4 MB 699.1 kB/s eta 0:00:03
#    ---------------------------------- ----- 10.7/12.4 MB 699.6 kB/s eta 0:00:03
#    ---------------------------------- ----- 10.7/12.4 MB 699.6 kB/s eta 0:00:03
#    ----------------------------------- ---- 11.0/12.4 MB 702.7 kB/s eta 0:00:03
#    ------------------------------------ --- 11.3/12.4 MB 708.6 kB/s eta 0:00:02
#    ------------------------------------- -- 11.5/12.4 MB 717.2 kB/s eta 0:00:02
#    ------------------------------------- -- 11.8/12.4 MB 721.6 kB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.4 MB 729.1 kB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.4 MB 729.1 kB/s eta 0:00:01
#    ---------------------------------------  12.3/12.4 MB 724.9 kB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 721.5 kB/s  0:00:18
# Installing collected packages: numpy
# Successfully installed numpy-2.4.1
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# Employee Details: Employee ID, Department, Number of Years with AtliQ
employee_details = np.array([
    [101, 'Sales', 3],  
    [102, 'HR', 5],    
    [103, 'IT', 2],        
    [104, 'Sales', 8],    
    [105, 'IT', 6],      
    [106, 'HR', 4],           
    [107, 'IT', 7],    
    [108, 'Sales', 1], 
    [109, 'HR', 3]          
])

# Survey Results: Employee ID, Happiness Score (1-10)
survey_results = np.array([
    [101, 8],
    [102, 10],
    [103, 9],
    [104, 6],
    [105, 7],
    [106, 8],
    [107, 9],
    [108, 5],
    [109, 7]
])

# Task 1: Merge Arrays
merged_data = np.hstack((employee_details, survey_results[:, 1].reshape(-1, 1)))
print(merged_data)
# Out:
# [['101' 'Sales' '3' '8']
#  ['102' 'HR' '5' '10']
#  ['103' 'IT' '2' '9']
#  ['104' 'Sales' '8' '6']
#  ['105' 'IT' '6' '7']
#  ['106' 'HR' '4' '8']
#  ['107' 'IT' '7' '9']
#  ['108' 'Sales' '1' '5']
#  ['109' 'HR' '3' '7']]

# %%
#Task 2: Print Scores
#Scenario: HR wants a quick view of all happiness scores to gauge overall employee sentiment.

#Action: Display all happiness scores from the merged array.
happiness_scores = merged_data[:, -1]
print("Happiness Scores:")
print(happiness_scores)
# Out:
# Happiness Scores:
# ['8' '10' '9' '6' '7' '8' '9' '5' '7']

# %%
#Task 3: Sort Scores
#Scenario: HR needs to identify the range of happiness scores to plan specific interventions.

#Action: Sort and print the happiness scores in ascending order.
sorted_happiness_scores = np.sort(happiness_scores)
print("Sorted Happiness Scores:")
print(sorted_happiness_scores)
# Out:
# Sorted Happiness Scores:
# ['10' '5' '6' '7' '7' '8' '8' '9' '9']

# %%
#Task 4: Employee Details
#Scenario: For a meeting, HR needs a list of employees' IDs and departments without other details.

#Action: Iterate through the array and print each employee's ID and department.
for employee in employee_details:
    print(f"Employee ID: {employee[0]}, Department: {employee[1]}")
# Out:
# Employee ID: 101, Department: Sales
# Employee ID: 102, Department: HR
# Employee ID: 103, Department: IT
# Employee ID: 104, Department: Sales
# Employee ID: 105, Department: IT
# Employee ID: 106, Department: HR
# Employee ID: 107, Department: IT
# Employee ID: 108, Department: Sales
# Employee ID: 109, Department: HR

# %%
#Task 5: Happiness Scores
#Scenario: HR wants to review individual happiness scores to follow up with specific departments or employees.

#Action: Print the happiness score alongside each employee ID from the merged array.
for employee in merged_data:
    print(f"Employee ID: {employee[0]}, Happiness Score: {employee[-1]}")
# Out:
# Employee ID: 101, Happiness Score: 8
# Employee ID: 102, Happiness Score: 10
# Employee ID: 103, Happiness Score: 9
# Employee ID: 104, Happiness Score: 6
# Employee ID: 105, Happiness Score: 7
# Employee ID: 106, Happiness Score: 8
# Employee ID: 107, Happiness Score: 9
# Employee ID: 108, Happiness Score: 5
# Employee ID: 109, Happiness Score: 7

# %%
#Task 6: Convert Scores
#Scenario: For statistical analysis, the HR team needs the happiness scores in a consistent format.

#Action: Convert the happiness scores to float type using astype(float).
happiness_scores_float = happiness_scores.astype(float)
print(happiness_scores_float)
# Out:
# [ 8. 10.  9.  6.  7.  8.  9.  5.  7.]

# %%
#Task 7: Average Score
#Scenario: To measure the effectiveness of current policies, HR needs the average happiness score.

#Action: Calculate and print the average happiness score of all employees.
average_happiness_score = np.mean(happiness_scores_float)
print(f"Average Happiness Score: {average_happiness_score}")
# Out:
# Average Happiness Score: 7.666666666666667

# %%
#Task 8: Unique Departments
#Scenario: HR is reviewing which departments are represented in the survey to ensure all are included in future plans.

#Action: Use np.unique to find and print all unique departments from the employee details.
unique_departments = np.unique(employee_details[:, 1])
print("Unique Departments:")
print(unique_departments)
# Out:
# Unique Departments:
# ['HR' 'IT' 'Sales']

# %%
#Task 9: HR Happiness
#Scenario: HR is conducting a self-assessment to understand how their own department perceives company policies.

#Action: Calculate and print the average happiness score within the HR department
hr_records = merged_data[employee_details[:, 1] == 'HR']
print(hr_records)

#########
hr_happiness_scores = hr_records[:, -1].astype(float)
print(hr_happiness_scores)

#####
average_hr_happiness = np.mean(hr_happiness_scores)
print("Average HR Happiness Score:", average_hr_happiness)
# Out:
# [['102' 'HR' '5' '10']
#  ['106' 'HR' '4' '8']
#  ['109' 'HR' '3' '7']]
# [10.  8.  7.]
# Average HR Happiness Score: 8.333333333333334
